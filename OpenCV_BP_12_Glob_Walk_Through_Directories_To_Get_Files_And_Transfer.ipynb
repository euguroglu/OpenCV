# %%
import glob
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %%
images = [cv2.imread(file) for file in glob.glob("C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/kaggle_3m/**/*.tif")]

# %%
image_names = [name for name in glob.glob("C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/kaggle_3m/**/*.tif")]

# %%
image_names[6].split("\\")[2]
# Out:
# 'TCGA_CS_4941_19960909_12_mask.tif'

# %%
for i,image in enumerate(images):
    cv2.imwrite('C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/brain/{}'.format(image_names[i].split("\\")[2]),image)

# %%
plt.imshow(a)

# %%
cv2.imshow('pic',a)
cv2.waitKey() #Windows will be open until hit any key
cv2.destroyAllWindows() #To shut down all window

# %%
image_names2[0].split("\\")[1]
# Out:
# 'TCGA_CS_4941_19960909_10_mask.tif'

# %%
image_names2 = [name for name in glob.glob("C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/valid2/*[!_mask].tif")]

# %%
images2 = [cv2.imread(file) for file in glob.glob("C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/valid2/*[!_mask].tif")]

# %%
for i,image in enumerate(images2):
    cv2.imwrite('C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/valid/{}'.format(image_names2[i].split("\\")[1]),image)

# %%
image_names2
# Out:
# ['C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_1.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_10.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_11.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_12.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_13.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_14.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_15.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_16.tif',
#  'C:/Users/PC/Documents/Jupyter/Segmentation/Brain_Segmentation/train2\\TCGA_CS_4941_19960909_17.tif',
# ...

# %%
plt.imshow(images2[0])
